# %%
import os
import pandas as pd
os.getcwd()
# Out:
# 'C:\\Users\\TanjasNB\\Documents\\Python Scripts'

# %%
df = pd.read_excel('LZ-Labor-Q-70.KL.SE.AK.221.xlsx','Eingabe_',index_col=None, header=None)

# %%
df.head(10)
# Out:
#               0   1   2   3                      4   5    6   7   \
# 0            NaN NaN NaN NaN                    NaN NaN  NaN NaN
# 1      Luftprobe NaN NaN NaN                    NaN NaN  NaN NaN
# 2  Probenahmeort NaN NaN NaN  Probenahme-\nvolumen  NaN  NaN NaN
# 3            NaN NaN NaN NaN                    NaN NaN  NaN NaN
# 4            NaN NaN NaN NaN                    NaN NaN  NaN NaN
# 5            NaN NaN NaN NaN                (Liter) NaN  NaN NaN
# 6         KL 1.1 NaN NaN NaN                   1000 NaN  NaN NaN
# 7         KL 1.2 NaN NaN NaN                   1000 NaN  NaN NaN
# 8        Kl  2.1 NaN NaN NaN                   1000 NaN  NaN NaN
# 9         KL 3.1 NaN NaN NaN                   1000 NaN  NaN NaN
#
#                        8    9   ...  22  23  24  25  26  27  28  29  30  \
# 0                     NaN  NaN  ... NaN NaN NaN NaN NaN NaN NaN NaN NaN
# 1                     NaN  NaN  ... NaN NaN NaN NaN NaN NaN NaN NaN NaN
# ...

# %%
df = df.dropna(axis='columns', how = 'all')
df[0].iloc[21]
# Out:
# 'Sedimentationsplatten (Durchm. 90 mm) '

# %%
se = df[0].iloc[21]
seort= df[0].iloc[25:35]
se_S = df[20].iloc[25:35]
se_P = df[16].iloc[25:35]
se_K = df[4].iloc[25:35]

# %% [markdown]
# Luftprobe

# %%
ak=df[0].iloc[36]
akort = df[0].iloc[40:81]
akort_pos = df[4].iloc[40:81]
ak_K = df[14].iloc[40:81]
ak_P =df[19].iloc[40:81]

# %% [markdown]
# Sedimentationsplatten

# %%
se.iloc[0]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-21-c083f8de971b> in <module>
# ----> 1 se.iloc[0]
#
# AttributeError: 'str' object has no attribute 'iloc'

# %% [raw]
# Kontaktplatten

# %%
kl = df[0].iloc[1]
klort = df[0].iloc[6:20]
kl_Volum = df[4].iloc[6:20]
kl_Platte = df[8].iloc[6:20]
kl_m3 = df[12].iloc[6:20]
kl_p = df[16].iloc[6:20]
kl_s = df[20].iloc[6:20]

# %%
# Out:
#   File "<ipython-input-45-bd6bf9430447>", line 1
#     {seort se_K se_P se_S}
#            ^
# SyntaxError: invalid syntax

# %%
data_se = {'Messort': seort,
        'Keime': se_K,
        'Pilzen':se_P,
        'Sporen':se_S
        }

# %%
df_se = pd.DataFrame(data_se, columns = ['Messort', 'Keime','Pilzen','Sporen'])

# %%
df_se
# Out:
#    Messort Keime Pilzen Sporen
# 25  SE 1.1   < 1    < 1    < 1
# 26  SE 1.2   < 1    < 1    < 1
# 27  SE 2.1   < 1    < 1    < 1
# 28  SE 3.1   < 1    < 1    < 1
# 29  SE 4.1   < 1    < 1    < 1
# 30  SE 4.2   < 1    < 1    < 1
# 31  SE 5.1   < 1    < 1    < 1
# 32  SE 5.2     1    < 1    < 1
# 33  SE 5.3   < 1    < 1    < 1
# 34  SE 5.4     2    < 1    < 1

# %%
data_kl = {'Messort': klort,
           'Volume':kl_Volum ,
           'Platte':kl_Platte,
           'in Volume':kl_m3,
           'Pilzen':kl_p,
        'Sporen':kl_s
        }
df_kl = pd.DataFrame(data_kl, columns = ['Messort', 'Volume','Platte','in Volume','Pilzen','Sporen'])

# %%
df_kl
# Out:
#     Messort Volume Platte in Volume Pilzen Sporen
# 6    KL 1.1   1000    < 1       < 1    < 1    < 1
# 7    KL 1.2   1000    < 1       < 1    < 1    < 1
# 8   Kl  2.1   1000    < 1       < 1    < 1    < 1
# 9    KL 3.1   1000      8         8      2    < 1
# 10   KL 4.1   1000      2         2      1    < 1
# 11   KL 4.2   1000      4         4      1    < 1
# 12   KL 5.1    200      3        15      5    < 1
# 13   KL 5.2    200      3        15     10    < 5
# 14   KL 5.3    200    < 1       < 5    < 5    < 5
# 15   KL 5.4    200      3        15      5    < 5
# 16   KL 5.5    200      3        15      5    < 5
# 17   KL 5.6    200    < 1       < 5    < 5    < 5
# 18   KL 5.7    200      1         5    < 5    < 5
# 19   KL 5.8    200    < 1       < 5    < 5    < 5

# %%
data_ak = {'Messort': akort,
           'Discription':akort_pos ,
           'Platte':ak_K,
           'Pilzen':ak_P
        
        }

df_ak = pd.DataFrame(data_ak, columns = ['Messort', 'Discription','Platte','Pilzen'])

# %%
df_ak
# Out:
#     Messort                     Discription Platte Pilzen
# 40   AK 1.1                    Wand (1.2 m)    < 1    < 1
# 41   AK 1.2   linker Arbeitsbereich (0.9 m)    < 1    < 1
# 42   AK 1.3       zentraler Bereich (0.9 m)    < 1    < 1
# 43   AK 1.4  rechter Arbeitsbereich (0.9 m)    < 1    < 1
# 44   AK 1.5   linker Arbeitsbereich (0.9 m)    < 1    < 1
# 45   AK 1.6       zentraler Bereich (0.9 m)    < 1    < 1
# 46   AK 1.7  rechter Arbeitsbereich (0.9 m)    < 1    < 1
# 47   AK 1.8                    Wand (1.2 m)    < 1    < 1
# 48   AK 2.1   linker Arbeitsbereich (0.9 m)    < 1    < 1
# 49   AK 2.2       zentraler Bereich (0.9 m)    < 1    < 1
# 50   AK 2.3  rechter Arbeitsbereich (0.9 m)    < 1    < 1
# 51   AK 2.4                    Wand (1.2 m)    < 1    < 1
# 52   AK 3.1   linker Arbeitsbereich (0.9 m)    < 1    < 1
# 53   AK 3.2       zentraler Bereich (0.9 m)      1    < 1
# 54   AK 3.3  rechter Arbeitsbereich (0.9 m)    < 1    < 1
# ...

# %%
df_ak = df_ak.replace({'Platte':'< 1'}, {'Platte': 0}, regex=True)

# %%
df_ak.Platte.iloc[:8]
# Out:
# 40    0
# 41    0
# 42    0
# 43    0
# 44    0
# 45    0
# 46    0
# 47    0
# Name: Platte, dtype: int64

# %%
 import numpy as np

# %%
np.arange(1, 8, 1)
# Out:
# array([1, 2, 3, 4, 5, 6, 7])

# %%
import matplotlib.pyplot as plt

plt.plot(df_ak.Messort.iloc[:8], df_ak.Platte.iloc[:8],'r*', label = 'Messwerten')
plt.plot(df_ak.Messort.iloc[4],  np.mean(df_ak.Platte.iloc[:8]), 'go', label= 'Mittelwert')
plt.ylabel('KBE/m$^3$')
plt.xlabel('Messpositionen')
plt.title('Istwerten Laminar Feld 1, Klasse A')
plt.grid(color='grey', linestyle='--', linewidth=1)
plt.legend(loc="upper left")
plt.show()

# %%
plt.plot(df_ak.Messort.iloc[8:12], df_ak.Platte.iloc[8:12],'r*', label = 'Messwerten')
plt.plot(df_ak.Messort.iloc[10],  np.mean(df_ak.Platte.iloc[8:12]), 'go', label= 'Mittelwert')
plt.ylabel('KBE/m$^3$')
plt.xlabel('Messpositionen')
plt.title('Istwerten Laminar Feld 2, Klasse A')
plt.grid(color='grey', linestyle='--', linewidth=1)
plt.legend(loc="upper left")
plt.show()

# %%
plt.plot(df_ak.Messort.iloc[12:15], df_ak.Platte.iloc[12:15],'r*', label = 'Messwerten')
plt.plot(df_ak.Messort.iloc[13],  np.mean(df_ak.Platte.iloc[12:15]), 'go', label= 'Mittelwert')
plt.ylabel('KBE/m$^3$')
plt.xlabel('Messpositionen')
plt.title('Istwerten Arbeitsbereich 3, Klasse B')
plt.grid(color='grey', linestyle='--', linewidth=1)
plt.legend(loc="upper left")
plt.show()

# %%
plt.plot(df_ak.Messort.iloc[15:21], df_ak.Platte.iloc[15:21],'r*', label = 'Messwerten')
plt.plot(df_ak.Messort.iloc[18],  np.mean(df_ak.Platte.iloc[15:21]), 'go', label= 'Mittelwert')
plt.ylabel('KBE/m$^3$')
plt.xlabel('Messpositionen')
plt.title('Istwerten Arbeitsbereich 4, Klasse B')
plt.grid(color='grey', linestyle='--', linewidth=1)
plt.legend(loc="upper left")
plt.show()

# %%
fig = plt.figure(figsize=(20, 10))

plt.plot(df_ak.Messort.iloc[21:], df_ak.Platte.iloc[21:],'r*', label = 'Messwerten')
plt.plot(df_ak.Messort.iloc[30],  np.mean(df_ak.Platte.iloc[21:]), 'go', label= 'Mittelwert')

plt.ylabel('KBE/m$^3$')
plt.xlabel('Messpositionen')

plt.title('Istwerten Labor (RNr. 19), Klasse C')
plt.grid(color='grey', linestyle='--', linewidth=1)
plt.legend(loc="upper left")
plt.show()
